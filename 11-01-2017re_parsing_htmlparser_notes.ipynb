# %%
import re

# %%
str1 = '<> lorem ipsum http://www.onest.pl/ https://www3.onest.pl/ss/df=/a /  D d/!?"> <div class </div>ontent="http://www.onet.pl/" /> '
x = '(https?://)?www\.[a-z]+\.[a-z]+'

# %%
m1  = re.search('(https?:\/\/)?([a-z]+\d\.^csr)?([a-z]+\.)?onet\.[a-z]+(/?[^\s"]*/?)*', h)
ind = m1.span()
print(ind)
h[ind[0]:ind[1]]


str2 = "iaaaadiwjid"
str2[1:]
# Out:
# (309, 328)
# 'aaaadiwjid'

# %%
f1 = re.finditer('(https?:\/\/)?([a-z]+\d\.)?([a-z]+\.)?onet\.[a-z]+(/?[^\s"]*/?)*', h)
for tok in f1:
    ind1 = tok.span()
    print(h[ind1[0]:ind1[1]])
# Out:
# http://www.onet.pl/
# http://wiadomosci.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn2.ico
# http://biznes.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico
# http://sport.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico
# http://film.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico
# http://muzyka.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico
# http://vod.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico
# http://www.onet.pl/staticurls.txt
# www.onet.pl::SG_VER1
# http://www.onet.pl
# http://m.onet.pl
# http://lib.onet.pl
# http://csr.onet.pl
# http://kropka.onet.pl
# http://www.onet.pl
# http://sympatia.onet.pl/logout-onet-iframe.html
# www.onet.pl::SG_VER_DEF
# http://sgqcvfjvr.onet.pl/YnVpbGQve21kdDZrZ1ZOfWRsQXBpL2RsLmxpYntrYW1NU0ZmWX0ubWluLmpz
# sgqcvfjvr.onet.pl/YnVpbGQve21kdDZrZ1ZOfWRsQXBpL2RsLmxpYntrYW1NU0ZmWX0ubWluLmpz
# onet.hit.gemius.pl/xgemius.js\
# csr.onet.pl/_s/csr-006/csr.jsx?site=GLOWNA&area=NOWASG&kwrd=SEGG%2BadbIock&lu=201610101033420029300226&IV=201610101034269302619495&slot0=flat-config&id0=onet-ad-flat-config&slot1=top&id1=onet-ad-top&ver=20161004_1423&flash=1&kvhtml5c=1&kvadtype=expand&AC=711d257fb5297357&dr=http%3A%2F%2Fwww.onet.pl%2F&callback=onetShowAsynchAds1&adf=1\
# lib.onet.pl/s.csr/adp/px.gif?ch=2&rn=0&ad_type=1\
# http://pomoc.onet.pl/46,4214,faq_serwis.html
# lib.onet.pl%2Fs.csr%2Fwhitelist%2F
# http://pomoc.onet.pl/46,4214,faq_serwis.html
# onet.pl\
# sgqcvfjvr.onet.pl/
# lib.onet.pl/s.csr/
# uz.onet.pl/e1Y3YXlHU0J9/build&quot;}
# onet.hit.gemius.pl/xgemius.js';
# http://kropka.onet.pl/_s/kropka/1?DV=www
# http://wiadomosci.onet.pl/
# http://eurosport.onet.pl/
# http://biznes.onet.pl/
# http://kobieta.onet.pl/
# http://moto.onet.pl/
# http://www.onet.pl/#lista-kultura
# http://muzyka.onet.pl/
# http://film.onet.pl/
# http://www.onet.pl/#lista-horyzonty
# http://www.onet.pl/#lista-turbo
# http://www.onet.pl/#lista-obserwowane
# http://www.onet.pl/
# http://szukaj.onet.pl/wyniki.html
# http://sympatia.onet.pl/?utm_source=onet.pl&amp;utm_medium=banner&amp;utm_campaign=ikona
# onet.pl&utm_medium=banner&utm_campaign=ikona
# onet.pl&amp;utm_medium=banner&amp;utm_campaign=ik
://kobieta.onet.pl/dom/jak-zrobic-odkazajacy-plyn-do-czyszczenia-dwa-przepisy-dzieki-nim-pozbedziesz-sie-z/0t290l
# http://kobieta.onet.pl/uroda/wlosy/najmodniejsze-kolory-wlosow-co-bedziemy-nosic-na-glowie-w-2017-roku/5p11cl
# http://ciekawe.onet.pl/zwierzeta/porady/dlaczego-pies-daje-mi-prezenty-na-powitanie,1,4953904,artykul.html
# http://kobieta.onet.pl/zdrowie/porady-ekspertow/seksuolog/najskrytsze-fantazje-erotyczne-mezczyzny/ttblg
# http://mojlepszyplan.onet.pl/artykul/lekcja-ekonomii-dla-najmlodszych-jak-nauczy,109.html#detail-title
# http://kobieta.onet.pl/zdrowie/porady-ekspertow/seksuolog/maz-przebiera-sie-w-damska-bielizne/mbqgz
# http://gry.onet.pl/artykuly/clash-of-beauties-2017-zobaczcie-zdjecia-z-polskiego-cosplayowego-kalendarza/nxsj8x
# http://muzyka.onet.pl/polska-muzyka-lat-80-i-90-czy-pamietasz-co-sie-wtedy-dzialo/ehn123
# http://kobieta.onet.pl/miod-nektar-bogow-co-o-nim-wiesz-sprawdz-quiz/czmrhg
# http://podroze.onet.pl/ciekawe/zimowa-noc-w-namiocie-w-alpach-oryginalna-atrakcja-w-szwajcarii/593x0k
# http://wiadomosci.onet.pl/ciekawostki/smiejesz-sie-z-wpadki-ministra-waszczykowskiego-sprobuj-rozwiazac-quiz-na-temat/qs35qe
# http://strefatajemnic.onet.pl/apokalipsa/wloski-superwulkan-obudzil-sie-po-niemal-500-latach-jest-niebezpieczny/89t5tp
# http://film.onet.pl/recenzje/serial-tabu-duch-i-mrok-recenzja/tnve72
# http://kobieta.onet.pl/zludzenia-optyczne-co-tu-widzisz-quiz/fc7gvn
# http://podroze.onet.pl/ciekawe/czy-wiesz-do-ktorego-kraju-naleza-te-wyspy/x0jsxq
# http://katalog.onet.pl/
# http://katalog.onet.pl/2459,dowcipy,k.html
# http://katalog.onet.pl/5555,kobiety,k.html
# http://katalog.onet.pl/8639,senniki,k.html
# http://katalog.onet.pl/13371,filmy-online,k.html
# http://katalog.onet.pl/6159,samochody,k.html
# http://katalog.onet.pl/3894,praca,k.html
# http://katalog.onet.pl/3760,lotto,k.html
# http://katalog.onet.pl/4496,diety-odchudzanie,k.html
# http://katalog.onet.pl/8823,fryzury,k.html
# http://katalog.onet.pl/2484,horoskopy,k.html
# http://katalog.onet.pl/2438,przepisy-kulinarne,k.html
# http://katalog.onet.pl/3359,mapy-atlasy,k.html
# http://katalog.onet.pl/
# http://www.onet.pl/
# http://ofirmie.onet.pl/
# http://ofirmie.onet.pl/polityka-prywatnosci
# http://reklama.onet.pl/
# http://ofirmie.onet.pl/0,0,0,PL,aktualne_ogloszenia,oferta.html

# %%
l = []
cnt = 0
while cnt < 100000:
    if len(h) < 10:
        print("done")
        break
    m = re.search('(https?:\/\/)?([a-z]+\d\.^csr)?([a-z]+\.)?onet\.[a-z]+(/?[^\s"]*/?)*', h)
    if m:
        ind = m.span()
        l.append(h[ind[0]:ind[1]])
        h = h[ind[1]:]
    cnt += 1
print(len(l))    
l
# Out:
# 323
# ['http://www.onet.pl/',
#  'http://wiadomosci.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn2.ico',
#  'http://biznes.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico',
#  'http://sport.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico',
#  'http://film.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico',
#  'http://muzyka.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico',
#  'http://vod.onet.pl/;icon-uri=http://ocdn.eu/paas-static/template-engine/fe68d370e51c1cd328a21f9ca3ebd3e0/faviconn.ico',
#  'http://www.onet.pl/staticurls.txt',
#  'www.onet.pl::SG_VER1',
#  'http://www.onet.pl',
#  'http://m.onet.pl',
#  'http://lib.onet.pl',
#  'http://csr.onet.pl',
#  'http://kropka.onet.pl',
#  'http://www.onet.pl',
#  'http://sympatia.onet.pl/logout-onet-iframe.html',
#  'www.onet.pl::SG_VER_DEF',
#  'http://sgqcvfjvr.onet.pl/YnVpbGQve21kdDZrZ1ZOfWRsQXBpL2RsLmxpYntrYW1NU0ZmWX0ubWluLmpz',
#  'sgqcvfjvr.onet.pl/YnVpbGQve21kdDZrZ1ZOfWRsQXBpL2RsLmxpYntrYW1NU0ZmWX0ubWluLmpz',
#  'onet.hit.gemius.pl/xgemius.js\\',
#  'csr.onet.pl/_s/csr-006/csr.jsx?site=GLOWNA&area=NOWASG&kwrd=SEGG%2BadbIock&lu=201610101033420029300226&IV=201610101034269302619495&slot0=flat-config&id0=onet-ad-flat-config&slot1=top&id1=onet-ad-top&ver=20161004_1423&flash=1&kvhtml5c=1&kvadtype=expand&AC=711d257fb5297357&dr=http%3A%2F%2Fwww.onet.pl%2F&callback=onetShowAsynchAds1&adf=1\\',
#  'lib.onet.pl/s.csr/adp/px.gif?ch=2&rn=0&ad_type=1\\',
#  'http://pomoc.onet.pl/46,4214,faq_serwis.html',
#  'lib.onet.pl%2Fs.csr%2Fwhitelist%2F',
#  'http://pomoc.onet.pl/46,4214,faq_serwis.html',
#  'onet.pl\\',
#  'sgqcvfjvr.onet.pl/',
#  'lib.onet.pl/s.csr/',
#  'uz.onet.pl/e1Y3YXlHU0J9/build&quot;}',
#  "onet.hit.gemius.pl/xgemius.js';",
#  'http://kropka.onet.pl/_s/kropka/1?DV=www',
#  'http://wiadomosci.onet.pl/',
#  'http://eurosport.onet.pl/',
#  'http://biznes.onet.pl/',
#  'http://kobieta.onet.pl/',
#  'http://moto.onet.pl/',
#  'http://www.onet.pl/#lista-kultura',
#  'http://muzyka.onet.pl/',
#  'http://film.onet.pl/',
#  'http://www.onet.pl/#lista-horyzonty',
#  'http://www.onet.pl/#lista-turbo',
#  'http://www.onet.pl/#lista-obserwowane',
#  'http://www.onet.pl/',
#  'http://szukaj.onet.pl/wyniki.html',
#  'http://sympatia.onet.pl/?utm_source=onet.pl&amp;utm_medium=banner&amp;utm_campaign=ikona',
#  'onet.pl&utm_medium=banner&utm_campaign=ikona',
#  'onet.pl&amp;utm_medium=banner&amp;utm_campaign=ikona',
#  'http://gry.onet.pl/online/?utm_source=onet.pl&amp;utm_medium=banner&amp;utm_campaign=ik
#  'http://wiadomosci.onet.pl/ciekawostki/smiejesz-sie-z-wpadki-ministra-waszczykowskiego-sprobuj-rozwiazac-quiz-na-temat/qs35qe',
#  'http://strefatajemnic.onet.pl/apokalipsa/wloski-superwulkan-obudzil-sie-po-niemal-500-latach-jest-niebezpieczny/89t5tp',
#  'http://film.onet.pl/recenzje/serial-tabu-duch-i-mrok-recenzja/tnve72',
#  'http://kobieta.onet.pl/zludzenia-optyczne-co-tu-widzisz-quiz/fc7gvn',
#  'http://podroze.onet.pl/ciekawe/czy-wiesz-do-ktorego-kraju-naleza-te-wyspy/x0jsxq',
#  'http://katalog.onet.pl/',
#  'http://katalog.onet.pl/2459,dowcipy,k.html',
#  'http://katalog.onet.pl/5555,kobiety,k.html',
#  'http://katalog.onet.pl/8639,senniki,k.html',
#  'http://katalog.onet.pl/13371,filmy-online,k.html',
#  'http://katalog.onet.pl/6159,samochody,k.html',
#  'http://katalog.onet.pl/3894,praca,k.html',
#  'http://katalog.onet.pl/3760,lotto,k.html',
#  'http://katalog.onet.pl/4496,diety-odchudzanie,k.html',
#  'http://katalog.onet.pl/8823,fryzury,k.html',
#  'http://katalog.onet.pl/2484,horoskopy,k.html',
#  'http://katalog.onet.pl/2438,przepisy-kulinarne,k.html',
#  'http://katalog.onet.pl/3359,mapy-atlasy,k.html',
#  'http://katalog.onet.pl/',
#  'http://www.onet.pl/',
#  'http://ofirmie.onet.pl/',
#  'http://ofirmie.onet.pl/polityka-prywatnosci',
#  'http://reklama.onet.pl/',
#  'http://ofirmie.onet.pl/0,0,0,PL,aktualne_ogloszenia,oferta.html']

# %%
# %%writefile parse_tree.py
import operator as op


def inorder_traversal(tree):
    if tree:
        inorder_traversal(tree.getLeftChild())
        print(tree.getRootVal())
        inorder_traversal(tree.getRightChild())


def postorder_traversal(tree):
    if tree:
        postorder_traversal(tree.getLeftChild())
        postorder_traversal(tree.getRightChild())
        print(tree.getRootVal())


def iterative_reduce(xs, f, start):
    while True:
        if not xs:
            return start
        else:
            xs, f, start = xs[1:], f, f(start, xs[0])
    return xs


class BinaryTree:
    def __init__(self, rootObj):
        self.key = rootObj
        self.parent = None
        self.leftChild = None
        self.rightChild = None

    def insertLeft(self, newNode):
        if self.leftChild == None:
            t = BinaryTree(newNode)
            self.leftChild = t
            t.parent = self
            # self.leftChild = BinaryTree(newNode)
        else:
            t = BinaryTree(newNode)
            t.parent = self
            t.leftChild = self.leftChild
            self.leftChild.parent = t
            self.leftChild = t

    def insertRight(self, newNode):
        if self.rightChild == None:
            t = BinaryTree(newNode)
            self.rightChild = t
            t.parent = self
            # self.rightChild = BinaryTree(newNode)
        else:
            t = BinaryTree(newNode)
            t.parent = self
            t.rightChild = self.rightChild
            self.rightChild.parent = t
            self.rightChild = t

    def getRightChild(self):
        return self.rightChild

    def getLeftChild(self):
        return self.leftChild

    def getParent(self):
        return self.parent

    def setRootVal(self, obj):
        self.key.append(obj)

    def getRootVal(self):
        return self.key

    def preorder(self):
        print(self.key)
        if self.leftChild:
            self.leftChild.preorder()
        if self.rightChild:
            self.rightChild.preorder()


exp = ['[', 'a', 'a', '(', 'b', 'b', '(', 'c', 'c', ')', 'b', '(', 'd', 'd', '{', 'e', 'e', '}', ')', ')', 'a', ']']


def buil_n_ary_parse_tree(exp):
    e_tree = BinaryTree([])
    current = e_tree
    ctr = 0
    ctr1 = 0
    ctr2 = 0
    for token in exp:
        if token == '<p>':
            if ctr == 0:
                current.insertRight(['<p>'])
                current = current.getRightChild()
                ctr += 1
            else:
                ctr += 1
                current.insertLeft('<p>')
                current = current.getLeftChild()
        elif token == '<mark>':
            if ctr1 == 0:
                current.insertRight(['<mark>'])
                current = current.getRightChild()
                ctr1 += 1
            else:
                ctr1 += 1
                current.insertLeft([])
                current = current.getLeftChild()

        elif (not token in ['<p>', '</p>', '<mark>', '</mark>']) and ctr is not 0:
            current.setRootVal(token)
        elif token == '</p>':
            ctr -= 1
            current = current.getParent()
        elif token == '</mark>':
            ctr1 -= 1
            current = current.getParent()
    return e_tree

    # parse_tree = buil_n_ary_parse_tree(exp)
    # inorder_traversal(parse_tree)


def split_input_elements(xs):
    result = []
    for i in range(len(xs)):
        result.append(xs[i].rsplit())
    return result


def split_input_and_to_int(xs):
    def helper(ys):
        l = list(map(int, ys))
        return l

    l1 = list(map(helper, xs))
    return l1


    # tags: html, head, body, meta, title, ul, h1, h2, li, a
def prepare_expression(exp):
    """takes a page as a list and make tags visible"""
    del_list = []
    l = len(exp)
    for i in range(l):
        if exp[i] == '<' and exp[i + 1] == 'p' and exp[i + 2] == '>':
                exp[i] = '<p>'
                exp[i + 1] = []
                exp[i + 2] = []
        if exp[i] == '<' and exp[i + 1] == '/' and exp[i + 2] == 'p' and exp[i + 3] == '>':
                exp[i] = '</p>'
                exp[i + 1] = []
                exp[i + 2] = []
                exp[i + 3] = []
        if exp[i] == '<' and exp[i] == 'b' and exp[i + 2] == '>':
                exp[i] = '<b>'
                exp[i + 1] = []
                exp[i + 2] = []
        if exp[i] == '<' and exp[i] == '/' and exp[i + 2] == 'b' and exp[i + 3] == '>':
                exp[i] = '</b>'
                exp[i + 1] = []
                exp[i + 2] = []
                exp[i + 3] = []
        if exp[i] == '<' and exp[i + 1] == 's' and exp[i + 2] == 't' and exp[i + 3] == 'r' and exp[i + 4] == 'o' and \
                            exp[i + 5] == 'n' and exp[i + 6] == 'g' and exp[i + 7] == '>':
                exp[i] = '<strong>'
                exp[i + 1] = []
                exp[i + 2] = []
                exp[i + 3] = []
                exp[i + 4] = []
                exp[i + 5] = []
                exp[i + 6] = []
        if exp[i] == '<' and exp[i + 1] == '/' and exp[i + 2] == 's' and exp[i + 3] == 't' and exp[i + 4] == 'r' and \
                            exp[i + 5] == 'o' and exp[i + 6] == 'n' and exp[i + 7] == 'g' and exp[i + 8] == '>':
                exp[i] = '</strong>'
                exp[i + 1] = []
                exp[i + 2] = []
                exp[i + 3] = []
                exp[i + 4] = []
                exp[i + 5] = []
                exp[i + 6] = []
                exp[i + 7] = []
                exp[i + 8] = []

        if exp[i] == '<' and exp[i + 1] == 'i' and exp[i + 2] == '>':
                exp[i] = '<i>'
                del_list.append(i + 1)
                del_list.append(i + 2)
        if exp[i] == '<' and exp[i + 1] == 'e' and exp[i + 2] == 'm' and exp[i + 3] == '>':
                exp[i] = '<em>'
                del_list.append(i + 1)
                del_list.append(i + 2)
                del_list.append(i + 3)
        if exp[i] == '<' and exp[i + 1] == 'm' and exp[i + 2] == 'a' and exp[i + 3] == 'r' and exp[i + 4] == 'k' and \
                            exp[i + 5] == '>':
                exp[i] = '<mark>'
                exp[i + 1] = []
                exp[i + 2] = []
                exp[i + 3] = []
                exp[i + 4] = []
                exp[i + 5] = []
        if exp[i] == '<' and exp[i + 1] == '/' and exp[i + 2] == 'm' and exp[i + 3] == 'a' and exp[i + 4] == 'r' and \
                            exp[i + 5] == 'k' and exp[i + 6] == '>':
                exp[i] = '</mark>'
                exp[i + 1] = []
                exp[i + 2] = []
                exp[i + 3] = []
                exp[i + 4] = []
                exp[i + 5] = []
                exp[i + 6] = []
        if exp[i] == '<' and exp[i + 1] == 's' and exp[i + 2] == 'm' and exp[i + 3] == 'a' and exp[i + 4] == 'l' and \
                            exp[i + 5] == 'l':
                exp[i] = '<small>'
                del_list.append(i + 1)
                del_list.append(i + 2)
                del_list.append(i + 3)
                del_list.append(i + 4)
                del_list.append(i + 5)
        if exp[i] == '<' and exp[i + 1] == 'i' and exp[i + 2] == 'n' and exp[i + 3] == 's':
                exp[i] == '<ins>'
                del_list.append(i + 1)
                del_list.append(i + 2)
                del_list.append(i + 3)
    for t in range(len(exp) - 1, -1, -1):
        if isinstance(exp[t], list):
            del (exp[t])
    return exp
# Out:
# Writing parse_tree.py

# %%
'''
with open('/home/lion/projects/python/blog_not_notebook/ternary_trees_html_parsing/html_example.txt') as f:
    lines = f.read().splitlines()
print("slista z linii stringu wejsciowego ", lines)
print("dlugosc tej listy  ", len(lines))
lst1 = list(map(list, lines))
lst = iterative_reduce(lst1, op.add, [])
    # lst2 = iterative_reduce(lst, op.add, '')
print("cale wejscie stokenizpowane i zlistowane ", lst)



lst2 = prepare_expression(lst)
print("------------------------------------------------------------------------------------------------------------------")
print("wyloskane pare tokenow  ", lst2)
tr = BinaryTree('')
tr = buil_n_ary_parse_tree(lst2)
print("travers sparsowanego htmla: ")
inorder_traversal(tr)
'''
# Out:
# '\nwith open(\'/home/lion/projects/python/blog_not_notebook/ternary_trees_html_parsing/html_example.txt\') as f:\n    lines = f.read().splitlines()\nprint("slista z linii stringu wejsciowego ", lines)\nprint("dlugosc tej listy  ", len(lines))\nlst1 = list(map(list, lines))\nlst = iterative_reduce(lst1, op.add, [])\n    # lst2 = iterative_reduce(lst, op.add, \'\')\nprint("cale wejscie stokenizpowane i zlistowane ", lst)\n\n\n\nlst2 = prepare_expression(lst)\nprint("------------------------------------------------------------------------------------------------------------------")\nprint("wyloskane pare tokenow  ", lst2)\ntr = BinaryTree(\'\')\ntr = buil_n_ary_parse_tree(lst2)\nprint("travers sparsowanego htmla: ")\ninorder_traversal(tr)\n'

# %%
from parse_tree import *

# %%
import urllib.request

# %%
import urllib.request
try:
    with urllib.request.urlopen('onet.pl&utm_medium=banner&utm_campaign=ikona') as response:
        html = response.read()
except:
    print("not happy")
# Out:
# not happy

# %%
type(html)
h = html.decode("utf-8")
